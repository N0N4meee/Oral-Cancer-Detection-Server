# %%
# !pip install -q streamlit pyngrok tensorflow pillow
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.0/9.0 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 113.1 MB/s eta 0:00:00

# %%
from pyngrok import ngrok
ngrok.set_auth_token("2wU9l7iufxobjnbtBbS0ILYCeVF_zLkWzZGQajNAwYmbM5Rt")
# !streamlit run app.py --server.port 8501 --server.address 0.0.0.0 &>/dev/null &
print(ngrok.connect(8501))
# Out:
# NgrokTunnel: "https://83b547f27366.ngrok-free.app" -> "http://localhost:8501"
